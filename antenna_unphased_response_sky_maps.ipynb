# %%
from gwdetectors import *
import matplotlib.pyplot as plt

# %%
Ligo = DETECTORS['L_aligo-design']
L_armlength = np.linalg.norm(Ligo.arms[0])

detector = TwoArmDetector('test', PSDS[KNOWN_PSDS[1]], (0, 0, 0), 
                          arms = ((L_armlength, 0, 0), (0, L_armlength, 0)), 
                          long_wavelength_approximation=False)

fsr = 1 / (2 * np.linalg.norm(Ligo.arms[0]))

# %%
res = 180
polarization = 0

phi = np.linspace(-np.pi, np.pi, res)
theta = np.linspace(0, np.pi,res)
Phi, Theta = np.meshgrid(phi, theta)

phi_flat = Phi.flatten()
theta_flat = Theta.flatten()

psi = np.full(np.shape(phi_flat), polarization)

freqs = np.linspace(0, fsr, 11)

F_plus, F_cross, F_x, F_y, F_b, F_l = detector._geographic_unphased_response(freqs, phi_flat, theta_flat, psi, 
                                                                             detector.arms, 
                                                                             long_wavelength_approximation=False)

# %%
fr = 10

Fp = F_plus[fr].reshape((res, res))
Fc = F_cross[fr].reshape((res, res))
Fx = F_x[fr].reshape((res, res))
Fy = F_y[fr].reshape((res, res))
Fb = F_b[fr].reshape((res, res))
Fl = F_l[fr].reshape((res, res))

# %%
# Create coordinate grid for plot (phi in [-pi, pi], theta in [-pi/2, pi/2])
phi = np.linspace(-np.pi, np.pi, res)
theta = np.linspace(-np.pi/2., np.pi/2.,res)
Phi, Theta = np.meshgrid(phi, theta)

# %% [markdown]
# ### Plots of magnitude

# %%
data = np.sqrt(np.abs(Fc) ** 2 + np.abs(Fp) ** 2)

# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='mollweide')
im = ax.pcolormesh(Phi,Theta, data, cmap=plt.cm.Reds) 
plt.colorbar(im)
plt.show()
#plt.savefig(f'Fc_sq+Fp_sq_{fr}.png')

# %%
data = np.abs(Fp)

# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='mollweide')
im = ax.pcolormesh(Phi,Theta, data, cmap=plt.cm.Reds) 
plt.colorbar(im)
plt.show()
#plt.savefig(f'Fp_{fr}.png')

# %%
data = np.abs(Fc)

# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='mollweide')
im = ax.pcolormesh(Phi,Theta, data, cmap=plt.cm.Reds) 
plt.colorbar(im)
plt.show()
#plt.savefig(f'Fc_{fr}.png')

# %%
data = np.abs(Fx)

# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='mollweide')
im = ax.pcolormesh(Phi,Theta, data, cmap=plt.cm.Reds) 
plt.colorbar(im)
plt.show()
#plt.savefig(f'Fx_{fr}.png')

# %%
data = np.abs(Fy)

# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='mollweide')
im = ax.pcolormesh(Phi,Theta, data, cmap=plt.cm.Reds) 
plt.colorbar(im)
plt.show()
#plt.savefig(f'Fy_{fr}.png')

# %%
data = np.abs(Fb)

# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='mollweide')
im = ax.pcolormesh(Phi,Theta, data, cmap=plt.cm.Reds) 
plt.colorbar(im)
plt.show()
#plt.savefig(f'Fb_{fr}.png')

# %%
data = np.abs(Fl)

# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='mollweide')
im = ax.pcolormesh(Phi,Theta, data, cmap=plt.cm.Reds) 
plt.colorbar(im)
plt.show()
#plt.savefig(f'Fl_{fr}.png')

# %% [markdown]
# ### Plots of phase

# %%
phase = np.arctan(Fp.imag, Fp.real)

# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='mollweide')
im = ax.pcolormesh(Phi,Theta, phase, cmap=plt.cm.plasma) 
plt.colorbar(im)
plt.show()

# %%
phase = np.arctan(Fc.imag, Fc.real)

# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='mollweide')
im = ax.pcolormesh(Phi,Theta, phase, cmap=plt.cm.plasma) 
plt.colorbar(im)
plt.show()

# %%
phase = np.arctan(Fx.imag, Fx.real)

# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='mollweide')
im = ax.pcolormesh(Phi,Theta, phase, cmap=plt.cm.plasma) 
plt.colorbar(im)
plt.show()

# %%
phase = np.arctan(Fy.imag, Fy.real)

# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='mollweide')
im = ax.pcolormesh(Phi,Theta, phase, cmap=plt.cm.plasma) 
plt.colorbar(im)
plt.show()

# %%
phase = np.arctan(Fb.imag, Fb.real)

# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='mollweide')
im = ax.pcolormesh(Phi,Theta, phase, cmap=plt.cm.plasma) 
plt.colorbar(im)
plt.show()

# %%
phase = np.arctan(Fl.imag, Fl.real)

# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='mollweide')
im = ax.pcolormesh(Phi,Theta, phase, cmap=plt.cm.plasma) 
plt.colorbar(im)
plt.show()
